# %%
#GOAL: Produce nice potential figure for RDA paper showing climatological YEARLY rainfall totals over wide area
#then, in panels b and c, show changes between '51-'79 and '80-'07, and then '80-'93 and '94-'07

# %%
import numpy as np
import numpy.ma as ma
import time
import os
import netCDF4 as nc
import matplotlib.pyplot as plt
# %matplotlib notebook
from shutil import copyfile

# %%
ferretdatapath = "/Users/Siwen/Desktop/ferret/fer_dsets/data/"
aphropath = "APHRO_MA_025deg_V1101."
years = np.arange(1951,2008)
print(years)
# Out:
# [1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962 1963 1964 1965
#  1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980
#  1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995
#  1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007]

# %%
P_asia_year = np.zeros((280,360,57))
stn_year = np.zeros((280,360,57)) #station coverage

# %%
for i in years:
    
    #Build filename
    filename = ferretdatapath + aphropath + str(i) + '.nc'
    print(filename)
    myf = nc.Dataset(filename, 'r')
    
    #Obtain fraction of different types of rainfall
    P =  myf.variables['precip'][:]
    stn = myf.variables['rstn'][:]

    #Find seasonal amounts of each type of rainfall
    yr=i-1951
    
    #leaving out day 366 in leap years for convenience
    P_asia_year[:,:,yr]=np.nanmean(P[0:365,:,:], axis=0)
    stn_year[:,:,yr]=np.nanmean(stn[0:365,:,:], axis=0)
    
    #myf.close()
# Out:
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1951.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1952.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1953.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1954.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1955.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1956.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1957.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1958.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1959.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1960.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1961.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1962.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1963.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1964.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1965.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1966.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1967.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1968.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1969.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1970.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1971.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1972.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1973.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1974.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1975.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1976.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1977.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1978.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1979.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1980.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1981.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1982.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1983.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1984.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1985.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1986.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1987.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1988.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1989.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1990.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1991.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1992.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1993.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1994.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1995.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1996.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1997.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1998.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.1999.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2000.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2001.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2002.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2003.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2004.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2005.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2006.nc
# /Users/Siwen/Desktop/ferret/fer_dsets/data/APHRO_MA_025deg_V1101.2007.nc

# %%
P_asia_year_mask = ma.array(P_asia_year, mask = np.isnan(P_asia_year))
P_asia_year_sum = P_asia_year_mask * 365

myfilename = 'P_asia_year.nc'

myfile = nc.Dataset(myfilename, 'w')

#SAVE EVERYTHING AS HANDY NETCDF FILE
long_dim = myfile.createDimension('long', 360)
lat_dim = myfile.createDimension('lat', 280)
years_dim = myfile.createDimension('years', None)

dim_tuple = ("lat","long","years")
P_asia = myfile.createVariable("P_asia_year", 'f8', dim_tuple)
P_asia_sum = myfile.createVariable("P_asia_year_sum", 'f8', dim_tuple)
stations = myfile.createVariable("stations", 'f8', dim_tuple)

P_asia[:] = P_asia_year_mask
P_asia_sum[:] = P_asia_year_sum
stations[:] = stn_year[:]

myfile.close()

# %%
#years of interest - start and end date, with index starting at 1 out of habit.
myfilename = '/Users/Siwen/Desktop/Ferret/bin/P_asia_year.nc'

rainfile = nc.Dataset(myfilename, 'r')


p1_yr_b = [1,30]
p1_yr_e = [29,43]
p2_yr_b = [30,44]
p2_yr_e = [57,57]

P_asia_diff = []
P_asia_sum_diff = []

#cycle through all time periods of interest and find changes in each type of rainfall b/w periods
for p1_b, p1_e, p2_b, p2_e, i in zip(p1_yr_b, p1_yr_e, p2_yr_b, p2_yr_e, np.arange(len(p1_yr_b))): 
    
    P_asia_diff.append(np.mean(P_asia_year_mask[:,:,p2_b-1:p2_e], axis=2) - \
                         np.mean(P_asia_year_mask[:,:,p1_b-1:p1_e], axis=2))
    
    P_asia_sum_diff.append(np.mean(P_asia_year_mask[:,:,p2_b-1:p2_e], axis=2) - \
                         np.mean(P_asia_year_mask[:,:,p1_b-1:p1_e], axis=2))

# %%
#BOOTSTRAPPING

#similar to china_rain_diff, do lots of bootstrapping at each spatial point.

#daysmth is defined above
niter = 100 #how many iterations each time?
filepath = "asia_rain_diff_pval_"
backuppath = "/Users/Siwen/Desktop/Ferret/bin/"

#netCDF output file formatting formatting
yearsout = str(p1_b+50) + str(p1_e+50) + "_" + str(p2_b+50) + str(p2_e+50) + "_"
fullname = filepath + str(niter) + "iter.nc"
backupname = backuppath + fullname

##the following is only to make sure that we don't exceed the bounds of the number of rows of actual data.
if os.path.isfile(fullname):

    print('WARNING - file already exists! Cannot overwrite.')
    return
            
print('Building new file.')
fileout = nc.Dataset(savefile, 'w')
long_dim = fileout.createDimension('long', 360)
lat_dim = fileout.createDimension('lat', 280)
record_dim = fileout.createDimension('records', None)

dim_tuple = ("lat","long","record")
pval_8007_5179 = fileout.createVariable("pval_8007_5179", 'f8', dim_tuple)
pval_9407_8093 = fileout.createVariable("pval_9407_8093", 'f8', dim_tuple)
    
pvals=np.array.zeros(360,280,2)
    
#P-VALUES OF TOTAL RAINFALL
for p1_b, p1_e, p2_b, p2_e, k in zip(p1_yr_b, p1_yr_e, p2_yr_b, p2_yr_e, np.arange(len(p1_yr_b))): 

    for i in range(360):
    
        for j in range(280):
    
            if ma.getmask(P_asia_year_mask[i,j,0]) == 0:
                pvals[i,j,k] = bs_means_diff([i,j,p1_b-1:p1_e],[i,j,p2_b-1:p2_e], niter)

    #backup to external directory
        if os.path.exists(backupname):
            os.remove(backupname)
        copyfile(fullname, backupname) #backs file up in case of corruption
# Out:
# <img src="data:image/png;base64,...">

# %%
ma.getmask(P_asia_year_mask[0,:,0])
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
fn = 'P_asia_year.nc'

rainfile = nc.Dataset(fn, 'r')
stn =  rainfile.variables['stations'][:]
stn_mask = ma.array(stn, mask=np.isnan(stn))
# Out:
# (280, 360, 57)

# %%
def smooth(P,dayrange,latrange):
    Psmooth=np.zeros(P.shape)
    
    ll=int((dayrange-1)/2)
    yy=int((latrange-1)/2)
    
    longs = P.shape[0]
    lats = P.shape[1]
    
    for d in range(longs):
        for j in range(lats):
            
            Ps = P[max(0,i-yy):min(longs,i+yy+1),max(0,j-yy):min(lats,j+yy+1)]
            Psmooth[d,j] = np.mean(np.mean(Ps))
    
    return Psmooth

# %%
stn_mask_smth = [smooth(x,9,9) for x in stn_mask]
# Out:
# //anaconda/lib/python3.5/site-packages/numpy/ma/core.py:4089: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c55ced7b6019> in <module>()
# ----> 1 stn_mask_smth = [smooth(x,9,9) for x in stn_mask]
#
# <ipython-input-40-c55ced7b6019> in <listcomp>(.0)
# ----> 1 stn_mask_smth = [smooth(x,9,9) for x in stn_mask]
#
# <ipython-input-39-4869a5eab429> in smooth(P, dayrange, latrange)
#      11         for j in range(lats):
#      12
# ---> 13             Ps = P[max(0,i-yy):min(longs,i+yy+1),max(0,j-yy):min(lats,j+yy+1)]
#      14             Psmooth[d,j] = np.mean(np.mean(Ps))
#      15
#
# //anaconda/lib/python3.5/site-packages/numpy/ma/core.py in __getitem__(self, indx)
#    3138         else:
#    3139             # Force dout to MA
# -> 3140             dout = dout.view(type(self))
#    3141             # Inherit attributes from self
#    3142             dout._update_from(self)
#
# KeyboardInterrupt:

# %%
fig1,ax1 = plt.subplots()
plt.pcolormesh(np.mean(stn_mask[140:252,160:328,0:19],2))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
fig2,ax2 = plt.subplots()
plt.pcolormesh(np.mean(stn_mask[140:252,160:328,19:38],2))
# Out:
# <img src="data:image/png;base64,...">

# %%
fig3,ax3 = plt.subplots()
plt.pcolormesh(np.mean(stn_mask[140:252,160:328,38:57],2))
# Out:
# <img src="data:image/png;base64,...">
